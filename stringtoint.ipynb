# %%
from __future__ import print_function
from pandas import read_csv

import numpy
dataset = read_csv('/home/aiying/Machinelearning/dataorigin.csv',low_memory=False)

import pandas as pd
import numpy as np

import random
import numpy as np
import matplotlib.pyplot as plt

dataset.fillna('N',inplace=True)
ds=dataset.values.tolist()   
headers=list(dataset)

# %%
C[1]

# %%
dataset['exprace']

# %%
dataset['exprace'].replace(
    to_replace=['.','brazilblack','brazilwhite','brazilbrown','chinese','dutch','malay'],
    value=['N','11','12','13','14','15','16'],
    inplace=True
)

# %%
C=[]
for i in range(0,144):
    C.append(set(list(dataset[headers[i]])))

# %%
C[1]

# %%
dataset['exprace'][112]

# %%
len(C[69])

# %%
dataset['citizenship'].replace(
    to_replace=['.',
 'AE',
 'AF',
 'AL',
 'AO',
 'AT',
 'AU',
 'BD',
 'BE',
 'BG',
 'BM',
 'BN',
 'BO',
 'BR',
 'BS',
 'BY',
 'CA',
 'CL',
 'CM',
 'CN',
 'CO',
 'CR',
 'CV',
 'CY',
 'CZ',
 'DE',
 'DK',
 'DM',
 'DO',
 'EC',
 'EG',
 'ES',
 'FI',
 'FR',
 'GH',
 'GR',
 'GT',
 'GW',
 'GY',
 'HK',
 'HN',
 'HT',
 'HU',
 'ID',
 'IE',
 'IL',
 'IN',
 'IQ',
 'IR',
 'IT',
 'JM',
 'JP',
 'KE',
 'KR',
 'KW',
 'KZ',
 'LA',
 'LK',
 'LT',
 'MA',
 'MH',
 'MK',
 'MO',
 'MV',
 'MX',
 'MY',
 'NG',
 'NI',
 'NL',
 'NP',
 'NZ',
 'PA',
 'PE',
 'PH',
 'PK',
 'PL',
 'PR',
 'PT',
 'PW',
 'PY',
 'RO',
 'RU',
 'SA',
 'SE',
 'SG',
 'SK',
 'SN',
 'SV',
 'TH',
 'TR',
 'TT',
 'TW',
 'UA',
 'UG',
 'UK',
 'US',
 'UZ',
 'VG',
 'VN',
 'ZA',
 'ZM',
 'other'],
    value=['N']+list(range(0,101)),
    inplace=True
)

# %%
dataset['exprace'].replace(
    to_replace=['.','brazilblack','brazilwhite','brazilbrown','chinese','dutch','malay'],
    value=['N','11','12','13','14','15','16'],
    inplace=True
)

# %%
C[103]

# %%
dataset[headers[103]]

# %%
dataset[headers[122]].replace(
    to_replace=['.','Other or Unknown',
 'American Indian/Alaska Native',
 'Belgisch Nederlands',
 'Black or African American',
 'Duits',
 'East Asian',
 'Marokkaans Nederlands',
 'More than one race - Black/White',
 'More than one race - Other',
 'Native Hawaiian or other Pacific Islander',
 'Nederlands',
 'Nederlandse',
 'Russian',
 'South Asian',
 'Turks Nederlands',
 'White',
 'brazilblack',
 'brazilbrown',
 'brazilindigenous',
 'brazilwhite',
 'brazilyellow',
 'chinese',
 'duits',
 'indian',
 'italiaans nederlands',
 'malay',
 'nederlands',
 'nl',
 'turk'],
    value=['N','N']+list(range(28)),
    inplace=True
)

# %%
dataset[headers[122]]

# %%
dataset.to_csv('/home/aiying/dataorigin.csv')

# %%
dt = read_csv('/home/aiying/dataorigin.csv',low_memory=False)

# %%
dt
# Out:
#       Unnamed: 0  Unnamed: 0.1 expgender exprace  separatedornot_nobarriers  \
# 0              0             0       1.0       6                          0
# 1              1             1       1.0       6                          0
# 2              2             2       1.0       6                          0
# 3              3             3       1.0       6                          0
# 4              4             4       1.0       6                          0
# 5              5             5       1.0       6                          0
# 6              6             6       1.0       6                          1
# 7              7             7       1.0       6                          0
# 8              8             8       1.0       6                          1
# 9              9             9       1.0       6                          0
# 10            10            10       1.0       6                          0
# ...

# %%
dt.replace('N', np.NaN,inplace=True)

# %%
dt
# Out:
#       Unnamed: 0  Unnamed: 0.1 expgender exprace  separatedornot_nobarriers  \
# 0              0             0       1.0       6                          0
# 1              1             1       1.0       6                          0
# 2              2             2       1.0       6                          0
# 3              3             3       1.0       6                          0
# 4              4             4       1.0       6                          0
# 5              5             5       1.0       6                          0
# 6              6             6       1.0       6                          1
# 7              7             7       1.0       6                          0
# 8              8             8       1.0       6                          1
# 9              9             9       1.0       6                          0
# 10            10            10       1.0       6                          0
# ...

# %%
dt.fillna(dt.median(),inplace=True)

# %%
dt
# Out:
#       Unnamed: 0  Unnamed: 0.1 expgender exprace  separatedornot_nobarriers  \
# 0              0             0       1.0       6                          0
# 1              1             1       1.0       6                          0
# 2              2             2       1.0       6                          0
# 3              3             3       1.0       6                          0
# 4              4             4       1.0       6                          0
# 5              5             5       1.0       6                          0
# 6              6             6       1.0       6                          1
# 7              7             7       1.0       6                          0
# 8              8             8       1.0       6                          1
# 9              9             9       1.0       6                          0
# 10            10            10       1.0       6                          0
# ...

# %%
dt.to_csv('/home/aiying/Machinelearning/addmeanorigin.csv')
