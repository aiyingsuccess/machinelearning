# %%
# For Python 2 / 3 compatability
from __future__ import print_function
from pandas import read_csv

import numpy
dataset = read_csv('/home/aiying/machinelearning/data1.csv')

import pandas as pd
import numpy as np


import random
import numpy as np
import matplotlib.pyplot as plt

testcolumn=4

dataset.fillna('N',inplace=True)
dataset.median()
dataset.to_csv('/home/aiying/machinelearning/addmean1.csv')
ds=dataset.values.tolist()

# %%
header=list(dataset)

# %%
header
# Out:
# ['expgender',
#  'separatedornot_nobarriers',
#  'separatedornot_other',
#  'separatedornot_separaterooms',
#  'age',
#  'sunkgroup',
#  'sunkDV',
#  'gainlossgroup',
#  'gainlossDV',
#  'anch1group',
#  'anch2group',
#  'anch3group',
#  'anch4group',
#  'anchoring1',
#  'anchoring2',
#  'anchoring3',
#  'anchoring4',
#  'Ranchori',
#  'RAN001',
#  'RAN002',
#  'RAN003',
#  'Ranch1',
#  'Ranch2',
#  'Ranch3',
#  'Ranch4',
#  'gambfalgroup',
#  'gambfalDV',
#  'scalesgroup',
#  'scalesreca',
#  'scalesrecb',
#  'scales',
#  'reciprocitygroup',
#  'reciprocityother',
#  'reciprocityus',
#  'allowedforbiddenGroup',
#  'allowedforbidden',
#  'quotearec',
#  'quotebrec',
#  'quoteGroup',
#  'quote',
#  'totalflagestimations',
#  'totalnoflagtimeestimations',
#  'flagfilter',
#  'flagdv',
#  'flagGroup',
#  'Sysjust',
#  'MoneyGroup',
#  'moneyfilter',
#  'ContactGroup',
#  'Imagineddv',
#  'IATfilter',
#  'partgender',
#  'IATexpart',
#  'IATexpmath',
#  'IATexp.overall',
#  'totexpmissed',
#  'IATEXPfilter',
#  'allowedforbiddena',
#  'allowedforbiddenb',
#  'anchoring1a',
#  'anchoring1b',
#  'anchoring2a',
#  'anchoring2b',
#  'anchoring3a',
#  'anchoring3b',
#  'anchoring4a',
#  'anchoring4b',
#  'artwarm',
#  'd_donotuse',
#  'diseaseframinga',
#  'diseaseframingb',
#  'ethnicity_X1',
#  'ethnicity_X2',
#  'ethnicity_X3',
#  'flagsupplement1',
#  'flagsupplement2',
#  'flagsupplement3',
#  'flagtimeestimate1_Afternoon',
#  'flagtimeestimate1_Evening',
#  'flagtimeestimate1_Morning',
#  'flagtimeestimate2_Afternoon',
#  'flagtimeestimate2_Evening',
#  'flagtimeestimate2_Morning',
#  'flagtimeestimate3_Afternoon',
#  'flagtimeestimate3_Evening',
#  'flagtimeestimate3_Morning',
#  'flagtimeestimate4_Afternoon',
#  'flagtimeestimate4_Evening',
#  'flagtimeestimate4_Morning',
#  'gamblerfallacya',
#  'gamblerfallacyb',
#  'imaginedexplicit1',
#  'imaginedexplicit2',
#  'imaginedexplicit3',
#  'imaginedexplicit4',
#  'major',
#  'mathwarm',
#  'moneyagea',
#  'moneyageb',
#  'moneygendera',
#  'moneygenderb',
#  'noflagtimeestimate1_Afternoon',
#  'noflagtimeestimate1_Evening',
#  'noflagtimeestimate1_Morning',
#  'noflagtimeestimate2_Afternoon',
#  'noflagtimeestimate2_Evening',
#  'noflagtimeestimate2_Morning',
#  'noflagtimeestimate3_Afternoon',
#  'noflagtimeestimate3_Evening',
#  'noflagtimeestimate3_Morning',
#  'noflagtimeestimate4_Afternoon',
#  'noflagtimeestimate4_Evening',
#  'noflagtimeestimate4_Morning',
#  'omdimc3',
#  'omdimc3rt',
#  'omdimc3trt',
#  'politicalid',
#  'quotea',
#  'quoteb',
#  'reciprocityothera',
#  'reciprocityotherb',
#  'reciprocityusa',
#  'reciprocityusb',
#  'scalesa',
#  'scalesb',
#  'sex',
#  'sunkcosta',
#  'sunkcostb',
#  'sysjust1',
#  'sysjust2',
#  'sysjust3',
#  'sysjust4',
#  'sysjust5',
#  'sysjust6',
#  'sysjust7',
#  'sysjust8',
#  'us_or_international',
#  'lab_or_online',
#  'order',
#  'iat_exclude']

# %%
ds[3][4]
# Out:
# 18.0

# %%
header
# Out:
# ['expgender',
#  'separatedornot_nobarriers',
#  'separatedornot_other',
#  'separatedornot_separaterooms',
#  'age',
#  'sunkgroup',
#  'sunkDV',
#  'gainlossgroup',
#  'gainlossDV',
#  'anch1group',
#  'anch2group',
#  'anch3group',
#  'anch4group',
#  'anchoring1',
#  'anchoring2',
#  'anchoring3',
#  'anchoring4',
#  'Ranchori',
#  'RAN001',
#  'RAN002',
#  'RAN003',
#  'Ranch1',
#  'Ranch2',
#  'Ranch3',
#  'Ranch4',
#  'gambfalgroup',
#  'gambfalDV',
#  'scalesgroup',
#  'scalesreca',
#  'scalesrecb',
#  'scales',
#  'reciprocitygroup',
#  'reciprocityother',
#  'reciprocityus',
#  'allowedforbiddenGroup',
#  'allowedforbidden',
#  'quotearec',
#  'quotebrec',
#  'quoteGroup',
#  'quote',
#  'totalflagestimations',
#  'totalnoflagtimeestimations',
#  'flagfilter',
#  'flagdv',
#  'flagGroup',
#  'Sysjust',
#  'MoneyGroup',
#  'moneyfilter',
#  'ContactGroup',
#  'Imagineddv',
#  'IATfilter',
#  'partgender',
#  'IATexpart',
#  'IATexpmath',
#  'IATexp.overall',
#  'totexpmissed',
#  'IATEXPfilter',
#  'allowedforbiddena',
#  'allowedforbiddenb',
#  'anchoring1a',
#  'anchoring1b',
#  'anchoring2a',
#  'anchoring2b',
#  'anchoring3a',
#  'anchoring3b',
#  'anchoring4a',
#  'anchoring4b',
#  'artwarm',
#  'd_donotuse',
#  'diseaseframinga',
#  'diseaseframingb',
#  'ethnicity_X1',
#  'ethnicity_X2',
#  'ethnicity_X3',
#  'flagsupplement1',
#  'flagsupplement2',
#  'flagsupplement3',
#  'flagtimeestimate1_Afternoon',
#  'flagtimeestimate1_Evening',
#  'flagtimeestimate1_Morning',
#  'flagtimeestimate2_Afternoon',
#  'flagtimeestimate2_Evening',
#  'flagtimeestimate2_Morning',
#  'flagtimeestimate3_Afternoon',
#  'flagtimeestimate3_Evening',
#  'flagtimeestimate3_Morning',
#  'flagtimeestimate4_Afternoon',
#  'flagtimeestimate4_Evening',
#  'flagtimeestimate4_Morning',
#  'gamblerfallacya',
#  'gamblerfallacyb',
#  'imaginedexplicit1',
#  'imaginedexplicit2',
#  'imaginedexplicit3',
#  'imaginedexplicit4',
#  'major',
#  'mathwarm',
#  'moneyagea',
#  'moneyageb',
#  'moneygendera',
#  'moneygenderb',
#  'noflagtimeestimate1_Afternoon',
#  'noflagtimeestimate1_Evening',
#  'noflagtimeestimate1_Morning',
#  'noflagtimeestimate2_Afternoon',
#  'noflagtimeestimate2_Evening',
#  'noflagtimeestimate2_Morning',
#  'noflagtimeestimate3_Afternoon',
#  'noflagtimeestimate3_Evening',
#  'noflagtimeestimate3_Morning',
#  'noflagtimeestimate4_Afternoon',
#  'noflagtimeestimate4_Evening',
#  'noflagtimeestimate4_Morning',
#  'omdimc3',
#  'omdimc3rt',
#  'omdimc3trt',
#  'politicalid',
#  'quotea',
#  'quoteb',
#  'reciprocityothera',
#  'reciprocityotherb',
#  'reciprocityusa',
#  'reciprocityusb',
#  'scalesa',
#  'scalesb',
#  'sex',
#  'sunkcosta',
#  'sunkcostb',
#  'sysjust1',
#  'sysjust2',
#  'sysjust3',
#  'sysjust4',
#  'sysjust5',
#  'sysjust6',
#  'sysjust7',
#  'sysjust8',
#  'us_or_international',
#  'lab_or_online',
#  'order',
#  'iat_exclude']

# %%
header.index('imaginedexplicit1')
# Out:
# 91
